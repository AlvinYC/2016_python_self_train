# %%
#encoding utf-8
import numpy as np
import pandas as pd
from IPython.display import Image
import json
import urllib2
from time import sleep

# %%
DTFQA = pd.read_pickle('./db/DTFQA_v02')
DTFQA.iloc[0:5,:]
# Out:
#   No.  utterances intent         entity     nlp_class nlp_name
# 0   1    請問洗手間在哪?    問門市  分店::內部資訊,洗手間;  NLP_Major_05     店內資訊
# 1   1   你們化妝室怎麼走?    問門市  分店::內部資訊,化妝室;  NLP_Major_05     店內資訊
# 2   1       我想上廁所    問門市   分店::內部資訊,廁所;  NLP_Major_05     店內資訊
# 3   3  什麼時候不需要排隊?    問門市     分店::候位,排隊;  NLP_Major_05     店內資訊
# 4   3      哪時候人最少    問門市    分店::候位,人最少;  NLP_Major_05     店內資訊

# %%
##################################
#     Jieba class definition
##################################
#data={u'sentence': u'我想吃晚餐'}

class jieba_seg(object):
    def __init__(self):
        self.jebareq = urllib2.Request('http://104.199.137.211/jieba_segmentation')
        self.ret_json = ()
        proxy = urllib2.ProxyHandler({})
        opener = urllib2.build_opener(proxy)
        urllib2.install_opener(opener)      
        
    def do_seg(self,data):
        ToDMDataJson=json.dumps(data)
         
        self.jebareq.add_header('Content-Type', 'application/json')
        f = urllib2.urlopen(self.jebareq, ToDMDataJson, timeout=12)                    
        decodejson= json.load(f)
        self.ret_json = json.dumps(decodejson, ensure_ascii=False)
        return self

# %%
term = np.array([])
pos  = np.array([])

DTFQA['term'] = 'small'
DTFQA['pos'] = 'small'
for i in range(len(DTFQA['No.'])):
    print DTFQA.get_value(i,'utterances')
    data = {u'sentence': DTFQA.get_value(i,'utterances')}
    jeba = jieba_seg()   
    jeba.do_seg(data)
    j_format = json.loads(jeba.ret_json)
    #pos = np.vstack((pos,j_format['pos']))
    #pos = np.concatenate((pos,np.array([j_format['pos']])))
    DTFQA['term'][i] = j_format['term']
    DTFQA['pos'][i] = j_format['pos']
    print repr(j_format['term']).decode("unicode-escape")
    print jeba.ret_json
    sleep(0.5)
# Out:
# 請問洗手間在哪?
# [u'請', u'問', u'洗手', u'間', u'在', u'哪', u'?']
# {"term": ["請", "問", "洗手", "間", "在", "哪", "?"], "pos": ["v", "v", "v", "f", "p", "r", "x"]}
# 你們化妝室怎麼走?
# [u'你們', u'化妝室', u'怎麼', u'走', u'?']
# {"term": ["你們", "化妝室", "怎麼", "走", "?"], "pos": ["r", "n", "r", "v", "x"]}
# 我想上廁所
# [u'我', u'想', u'上', u'廁所']
# {"term": ["我", "想", "上", "廁所"], "pos": ["r", "v", "f", "n"]}
# 什麼時候不需要排隊?
# [u'什麼', u'時候', u'不', u'需要', u'排隊', u'?']
# {"term": ["什麼", "時候", "不", "需要", "排隊", "?"], "pos": ["r", "n", "d", "v", "n", "x"]}
# 哪時候人最少
# [u'哪時候', u'人', u'最少']
# {"term": ["哪時候", "人", "最少"], "pos": ["r", "n", "d"]}
# 哪個時段不用候位
# [u'哪個', u'時段', u'不用', u'候位']
# {"term": ["哪個", "時段", "不用", "候位"], "pos": ["r", "n", "v", "n"]}
# 你們員工的待遇是不是很高?
# [u'你們', u'員工', u'的', u'待遇', u'是不是', u'很', u'高', u'?']
# {"term": ["你們", "員工", "的", "待遇", "是不是", "很", "高", "?"], "pos": ["r", "n", "uj", "n", "l", "d", "a", "x"]}
# 服務人員的薪水很高吧
# [u'服務', u'人員', u'的', u'薪水', u'很', u'高', u'吧']
# {"term": ["服務", "人員", "的", "薪水", "很", "高", "吧"], "pos": ["vn", "n", "uj", "n", "d", "a", "y"]}
# 你們福利是不是很棒?
# [u'你們', u'福利', u'是不是', u'很', u'棒', u'?']
# {"term": ["你們", "福利", "是不是", "很", "棒", "?"], "pos": ["r", "ns", "l", "d", "a", "x"]}
# 店內服務生的素質都很棒，是否都挑選過?
# [u'店', u'內', u'服務生', u'的', u'素質', u'都', u'很', u'棒', u'，', u'是否', u'都', u'挑選', u'過', u'?']
# {"term": ["店", "內", "服務生", "的", "素質", "都", "很", "棒", "，", "是否", "都", "挑選", "過", "?"], "pos": ["n", "f", "n", "uj", "n", "d", "d", "a", "x", "v", "d", "v", "ug", "x"]}
# 你們服務生都很專業耶，服務很貼心
# [u'你們', u'服務生', u'都', u'很', u'專業', u'耶', u'，', u'服務', u'很', u'貼心']
# {"term": ["你們", "服務生", "都", "很", "專業", "耶", "，", "服務", "很", "貼心"], "pos": ["r", "n", "d", "d", "n", "nr", "x", "vn", "d", "v"]}
# 我發現服務生都很親切，真的很棒
# [u'我', u'發現', u'服務', u'生都', u'很', u'親切', u'，', u'真的', u'很', u'棒']
# {"term": ["我", "發現", "服務", "生都", "很", "親切", "，", "真的", "很", "棒"], "pos": ["r", "v", "vn", "n", "d", "a", "x", "d", "d", "a"]}
# 服務生有受過特別訓練嗎?
# [u'服務', u'生有', u'受過', u'特別', u'訓練', u'嗎', u'?']
# {"term": ["服務", "生有", "受過", "特別", "訓練", "嗎", "?"], "pos": ["vn", "vn", "v", "d", "vn", "y", "x"]}
# 你們的教育訓練一定很辛苦吧
# [u'你們', u'的', u'教育', u'訓練', u'一定', u'很', u'辛苦', u'吧']
# {"term": ["你們", "的", "教育", "訓練", "一定", "很", "辛苦", "吧"], "pos": ["r", "uj", "vn", "vn", "d", "zg", "a", "y"]}
# 你們是怎麼訓練服務生的?
# [u'你們', u'是', u'怎麼', u'訓練', u'服務生', u'的', u'?']
# {"term": ["你們", "是", "怎麼", "訓練", "服務生", "的", "?"], "pos": ["r", "v", "r", "vn", "n", "uj", "x"]}
# 鼎泰豐收信用卡嗎?
# [u'鼎泰豐', u'收', u'信用卡', u'嗎', u'?']
# {"term": ["鼎泰豐", "收", "信用卡", "嗎", "?"], "pos": ["inoun", "v", "n", "x", "x"]}
# 只能付現金嗎?
# [u'只能', u'付現', u'金', u'嗎', u'?']
# {"term": ["只能", "付現", "金", "嗎", "?"], "pos": ["v", "v", "ng", "y", "x"]}
# 可以刷卡嗎?
# [u'可以', u'刷卡', u'嗎', u'?']
# {"term": ["可以", "刷卡", "嗎", "?"], "pos": ["c", "n", "x", "x"]}
# 信義店為何沒有提供信用卡刷卡服務的問題?
# [u'信義', u'店', u'為何', u'沒有', u'提供', u'信用卡', u'刷卡', u'服務', u'的', u'問題', u'?']
# {"term": ["信義", "店", "為何", "沒有", "提供", "信用卡", "刷卡", "服務", "的", "問題", "?"], "pos": ["inoun", "n", "r", "v", "v", "n", "n", "vn", "uj", "n", "x"]}
# 為什麼信義店只能付現?
# [u'為', u'什麼', u'信義', u'店', u'只能', u'付現', u'?']
# {"term": ["為", "什麼", "信義", "店", "只能", "付現", "?"], "pos": ["p", "r", "inoun", "n", "v", "v", "x"]}
# 除了信義店外，還有其他店不能刷卡嗎?
# [u'除了', u'信義', u'店', u'外', u'，', u'還', u'有', u'其他', u'店', u'不能', u'刷卡', u'嗎', u'?']
# {"term": ["除了", "信義", "店", "外", "，", "還", "有", "其他", "店", "不能", "刷卡", "嗎", "?"], "pos": ["p", "inoun", "n", "f", "x", "d", "v", "r", "n", "v", "n", "x", "x"]}
# 海外分店餐點和台灣門市餐點的不同?
# [u'海外', u'分店', u'餐點', u'和', u'台灣門市', u'餐點', u'的', u'不同', u'?']
# {"term": ["海外", "分店", "餐點", "和", "台灣門市", "餐點", "的", "不同", "?"], "pos": ["s", "n", "n", "c", "ns", "n", "uj", "a", "x"]}
# 國外的分店的餐點和台灣會不一樣嗎?
# [u'國外', u'的', u'分店', u'的', u'餐點', u'和', u'台灣', u'會', u'不一', u'樣', u'嗎', u'?']
# {"term": ["國外", "的", "分店", "的", "餐點", "和", "台灣", "會", "不一", "樣", "嗎", "?"], "pos": ["s", "uj", "n", "uj", "n", "c", "ns", "v", "c", "q", "y", "x"]}
# 國外門市賣的東西會比較多樣嗎?
# [u'國外', u'門市', u'賣', u'的', u'東西會', u'比較', u'多樣', u'嗎', u'?']
# {"term": ["國外", "門市", "賣", "的", "東西會", "比較", "多樣", "嗎", "?"], "pos": ["s", "n", "v", "uj", "n", "d", "r", "y", "x"]}
# 店內的消費好像不便宜?
# [u'店', u'內', u'的', u'消費', u'好像', u'不便', u'宜', u'?']
# {"term": ["店", "內", "的", "消費", "好像", "不便", "宜", "?"], "pos": ["n", "f", "uj", "vn", "v", "c", "vg", "x"]}
# 你們家的東西好貴喔
# [u'你們', u'家', u'的', u'東西', u'好貴', u'喔']
# {"term": ["你們", "家", "的", "東西", "好貴", "喔"], "pos": ["r", "q", "uj", "ns", "a", "e"]}
# 為什麼你們要賣這麼貴?
# [u'為', u'什麼', u'你們', u'要', u'賣', u'這麼', u'貴', u'?']
# {"term": ["為", "什麼", "你們", "要", "賣", "這麼", "貴", "?"], "pos": ["p", "r", "r", "v", "v", "r", "n", "x"]}
# 鼎泰豐賣的是港式點心嗎?
# [u'鼎泰豐', u'賣', u'的', u'是', u'港式', u'點', u'心', u'嗎', u'?']
# {"term": ["鼎泰豐", "賣", "的", "是", "港式", "點", "心", "嗎", "?"], "pos": ["inoun", "v", "uj", "v", "inoun", "m", "n", "y", "x"]}
# 你們算港式點心嗎
# [u'你們', u'算', u'港式', u'點', u'心', u'嗎']
# {"term": ["你們", "算", "港式", "點", "心", "嗎"], "pos": ["r", "v", "inoun", "m", "n", "y"]}
# 鼎泰豐是港式餐廳嗎?
# [u'鼎泰豐', u'是', u'港式', u'餐廳', u'嗎', u'?']
# {"term": ["鼎泰豐", "是", "港式", "餐廳", "嗎", "?"], "pos": ["inoun", "v", "inoun", "n", "y", "x"]}
# 你們的茶是什麼茶?
# [u'你們', u'的', u'茶', u'是', u'什麼', u'茶', u'?']
# {"term": ["你們", "的", "茶", "是", "什麼", "茶", "?"], "pos": ["r", "uj", "n", "v", "r", "n", "x"]}
# 你們的茶是哪種茶葉?
# [u'你們', u'的', u'茶', u'是', u'哪種', u'茶葉', u'?']
# {"term": ["你們", "的", "茶", "是", "哪種", "茶葉", "?"], "pos": ["r", "uj", "n", "v", "r", "inoun", "x"]}
# 店內客人喝的是甚麼茶?
# [u'店', u'內', u'客人', u'喝', u'的', u'是', u'甚麼', u'茶', u'?']
# {"term": ["店", "內", "客人", "喝", "的", "是", "甚麼", "茶", "?"], "pos": ["n", "f", "n", "vg", "uj", "v", "r", "n", "x"]}
# 茶好好喝，是什麼茶阿?
# [u'茶', u'好', u'好喝', u'，', u'是', u'什麼', u'茶', u'阿', u'?']
# {"term": ["茶", "好", "好喝", "，", "是", "什麼", "茶", "阿", "?"], "pos": ["n", "a", "v", "x", "v", "r", "n", "nr", "x"]}
# 你們用的是哪種茶葉?
# [u'你們', u'用', u'的', u'是', u'哪種', u'茶葉', u'?']
# {"term": ["你們", "用", "的", "是", "哪種", "茶葉", "?"], "pos": ["r", "p", "uj", "v", "r", "inoun", "x"]}
# 茶葉是哪裡的?
# [u'茶葉', u'是', u'哪裡', u'的', u'?']
# {"term": ["茶葉", "是", "哪裡", "的", "?"], "pos": ["inoun", "v", "r", "uj", "x"]}
# 茶葉的產地
# [u'茶葉', u'的', u'產地']
# {"term": ["茶葉", "的", "產地"], "pos": ["inoun", "uj", "n"]}
# 你們家的茶也很好喝，產地在哪?
# [u'你們', u'家', u'的', u'茶', u'也', u'很', u'好喝', u'，', u'產地', u'在', u'哪', u'?']
# {"term": ["你們", "家", "的", "茶", "也", "很", "好喝", "，", "產地", "在", "哪", "?"], "pos": ["r", "q", "uj", "n", "d", "d", "v", "x", "n", "p", "r", "x"]}
# 我喜歡你們的茶，可以告訴我是哪種茶嗎?
# [u'我', u'喜歡', u'你們', u'的', u'茶', u'，', u'可以', u'告訴', u'我', u'是', u'哪種', u'茶', u'嗎', u'?']
# {"term": ["我", "喜歡", "你們", "的", "茶", "，", "可以", "告訴", "我", "是", "哪種", "茶", "嗎", "?"], "pos": ["r", "ipos", "r", "uj", "n", "x", "c", "v", "r", "v", "r", "n", "y", "x"]}
# 我想知道你們的茶是用甚麼茶葉
# [u'我', u'想', u'知道', u'你們', u'的', u'茶', u'是', u'用', u'甚麼', u'茶葉']
# {"term": ["我", "想", "知道", "你們", "的", "茶", "是", "用", "甚麼", "茶葉"], "pos": ["r", "v", "v", "r", "uj", "n", "v", "p", "r", "inoun"]}
# 小籠包為什麼吃起來這麼多汁?
# [u'小籠包', u'為', u'什麼', u'吃', u'起來', u'這麼', u'多', u'汁', u'?']
# {"term": ["小籠包", "為", "什麼", "吃", "起來", "這麼", "多", "汁", "?"], "pos": ["inoun", "p", "r", "v", "v", "r", "m", "ng", "x"]}
# 為什麼小籠包的湯汁會這麼多?
# [u'為', u'什麼', u'小籠包', u'的', u'湯', u'汁', u'會', u'這麼', u'多', u'?']
# {"term": ["為", "什麼", "小籠包", "的", "湯", "汁", "會", "這麼", "多", "?"], "pos": ["p", "r", "inoun", "uj", "n", "ng", "v", "r", "m", "x"]}
# 小籠包這麼多汁是有甚麼獨門秘方嗎?
# [u'小籠包', u'這麼', u'多', u'汁', u'是', u'有', u'甚麼', u'獨門', u'秘方', u'嗎', u'?']
# {"term": ["小籠包", "這麼", "多", "汁", "是", "有", "甚麼", "獨門", "秘方", "嗎", "?"], "pos": ["inoun", "r", "m", "ng", "v", "v", "r", "v", "n", "x", "x"]}
# 為什麼小籠包會這麼好吃
# [u'為', u'什麼', u'小籠包', u'會', u'這麼', u'好吃']
# {"term": ["為", "什麼", "小籠包", "會", "這麼", "好吃"], "pos": ["p", "r", "inoun", "v", "r", "v"]}
# 小籠包加了甚麼，為什麼湯汁就是比別人多
# [u'小籠包', u'加', u'了', u'甚麼', u'，', u'為', u'什麼', u'湯', u'汁', u'就是', u'比', u'別人', u'多']
# {"term": ["小籠包", "加", "了", "甚麼", "，", "為", "什麼", "湯", "汁", "就是", "比", "別人", "多"], "pos": ["inoun", "v", "ul", "r", "x", "p", "r", "n", "ng", "d", "p", "r", "m"]}
# 小籠包為什麼會有湯汁?
# [u'小籠包', u'為', u'什麼', u'會', u'有', u'湯', u'汁', u'?']
# {"term": ["小籠包", "為", "什麼", "會", "有", "湯", "汁", "?"], "pos": ["inoun", "p", "r", "v", "v", "n", "ng", "x"]}
# 小籠包裡面包了甚麼
# [u'小籠包', u'裡', u'面包', u'了', u'甚麼']
# {"term": ["小籠包", "裡", "面包", "了", "甚麼"], "pos": ["inoun", "zg", "n", "ul", "r"]}
# 小籠包的湯汁是怎麼來的
# [u'小籠包', u'的', u'湯', u'汁', u'是', u'怎麼', u'來', u'的']
# {"term": ["小籠包", "的", "湯", "汁", "是", "怎麼", "來", "的"], "pos": ["inoun", "uj", "n", "ng", "v", "r", "v", "uj"]}
# 你們的小籠包為什麼跟別人不同
# [u'你們', u'的', u'小籠包', u'為', u'什麼', u'跟', u'別人', u'不同']
# {"term": ["你們", "的", "小籠包", "為", "什麼", "跟", "別人", "不同"], "pos": ["r", "uj", "inoun", "p", "r", "p", "r", "a"]}
# 我想問一下小籠包為什麼這麼多汁?
# [u'我', u'想', u'問', u'一下', u'小籠包', u'為', u'什麼', u'這麼', u'多', u'汁', u'?']
# {"term": ["我", "想", "問", "一下", "小籠包", "為", "什麼", "這麼", "多", "汁", "?"], "pos": ["r", "v", "v", "m", "inoun", "p", "r", "r", "m", "ng", "x"]}
# 小籠湯包與小籠包有什麼不同?
# [u'小籠湯包', u'與', u'小籠包', u'有什麼', u'不同', u'?']
# {"term": ["小籠湯包", "與", "小籠包", "有什麼", "不同", "?"], "pos": ["inoun", "zg", "inoun", "r", "a", "x"]}
# 我想比較一下小籠湯包與小籠包
# [u'我', u'想', u'比較', u'一下', u'小籠湯包', u'與', u'小籠包']
# {"term": ["我", "想", "比較", "一下", "小籠湯包", "與", "小籠包"], "pos": ["r", "v", "d", "m", "inoun", "zg", "inoun"]}
# 小籠湯包與小籠包差在哪?
# [u'小籠湯包', u'與', u'小籠包', u'差', u'在', u'哪', u'?']
# {"term": ["小籠湯包", "與", "小籠包", "差", "在", "哪", "?"], "pos": ["inoun", "zg", "inoun", "a", "p", "r", "x"]}
# 小籠湯包與小籠包有甚麼不一樣?
# [u'小籠湯包', u'與', u'小籠包', u'有', u'甚麼', u'不一', u'樣', u'?']
# {"term": ["小籠湯包", "與", "小籠包", "有", "甚麼", "不一", "樣", "?"], "pos": ["inoun", "zg", "inoun", "v", "r", "c", "x", "x"]}
# 小籠湯包與小籠包的不同處在哪
# [u'小籠湯包', u'與', u'小籠包', u'的', u'不同', u'處', u'在', u'哪']
# {"term": ["小籠湯包", "與", "小籠包", "的", "不同", "處", "在", "哪"], "pos": ["inoun", "zg", "inoun", "uj", "a", "n", "p", "r"]}
# 小籠湯包和小籠包哪裡不一樣
# [u'小籠湯包', u'和', u'小籠包', u'哪裡', u'不一', u'樣']
# {"term": ["小籠湯包", "和", "小籠包", "哪裡", "不一", "樣"], "pos": ["inoun", "c", "inoun", "r", "c", "x"]}
# 幫我介紹一下小籠湯包和小籠包差別
# [u'幫', u'我', u'介紹', u'一下', u'小籠湯包', u'和', u'小籠包', u'差別']
# {"term": ["幫", "我", "介紹", "一下", "小籠湯包", "和", "小籠包", "差別"], "pos": ["v", "r", "v", "m", "inoun", "c", "inoun", "d"]}
# 我想了解一下小籠湯包和小籠包
# [u'我', u'想', u'了解', u'一下', u'小籠湯包', u'和', u'小籠包']
# {"term": ["我", "想", "了解", "一下", "小籠湯包", "和", "小籠包"], "pos": ["r", "v", "v", "m", "inoun", "c", "inoun"]}
# 小籠湯包和小籠包是一樣的嗎
# [u'小籠湯包', u'和', u'小籠包', u'是', u'一樣', u'的', u'嗎']
# {"term": ["小籠湯包", "和", "小籠包", "是", "一樣", "的", "嗎"], "pos": ["inoun", "c", "inoun", "v", "u", "uj", "y"]}
# 小籠湯包與小籠包介紹
# [u'小籠湯包', u'與', u'小籠包', u'介紹']
# {"term": ["小籠湯包", "與", "小籠包", "介紹"], "pos": ["inoun", "zg", "inoun", "v"]}
# 因為宗教因素不吃豬肉，請問蒸籠類鹹的哪些不含豬肉？
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請', u'問', u'蒸籠', u'類', u'鹹', u'的', u'哪些', u'不', u'含', u'豬', u'肉', u'？']
# {"term": ["因為", "宗教", "因素", "不吃", "豬肉", "，", "請", "問", "蒸籠", "類", "鹹", "的", "哪些", "不", "含", "豬", "肉", "？"], "pos": ["c", "n", "n", "v", "n", "x", "v", "v", "inoun", "q", "y", "uj", "r", "d", "v", "n", "n", "x"]}
# 請問那些東西沒有豬肉
# [u'請', u'問', u'那些', u'東西', u'沒有', u'豬肉']
# {"term": ["請", "問", "那些", "東西", "沒有", "豬肉"], "pos": ["v", "v", "r", "ns", "v", "n"]}
# 幫我列出不含豬肉的餐點
# [u'幫', u'我', u'列出', u'不含', u'豬肉', u'的', u'餐點']
# {"term": ["幫", "我", "列出", "不含", "豬肉", "的", "餐點"], "pos": ["v", "r", "v", "v", "n", "uj", "n"]}
# 我不能吃豬肉
# [u'我', u'不能', u'吃', u'豬', u'肉']
# {"term": ["我", "不能", "吃", "豬", "肉"], "pos": ["r", "v", "v", "n", "n"]}
# 有不含豬肉的餐點嗎
# [u'有', u'不', u'含', u'豬', u'肉', u'的', u'餐點', u'嗎']
# {"term": ["有", "不", "含", "豬", "肉", "的", "餐點", "嗎"], "pos": ["v", "d", "v", "n", "n", "uj", "n", "y"]}
# 蒸籠類 沒有豬肉的
# [u'蒸籠', u'類', u' ', u'沒有', u'豬肉', u'的']
# {"term": ["蒸籠", "類", " ", "沒有", "豬肉", "的"], "pos": ["inoun", "zg", "x", "v", "n", "uj"]}
# 我想吃蒸的東西，但我不能吃豬
# [u'我', u'想', u'吃', u'蒸', u'的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# {"term": ["我", "想", "吃", "蒸", "的", "東西", "，", "但", "我", "不能", "吃", "豬"], "pos": ["r", "v", "v", "v", "uj", "ns", "x", "c", "r", "v", "v", "n"]}
# 幫我列出除了有豬肉以外的蒸籠類餐點
# [u'幫', u'我', u'列出', u'除了', u'有', u'豬', u'肉', u'以外', u'的', u'蒸籠', u'類', u'餐點']
# {"term": ["幫", "我", "列出", "除了", "有", "豬", "肉", "以外", "的", "蒸籠", "類", "餐點"], "pos": ["v", "r", "v", "p", "v", "n", "n", "c", "uj", "inoun", "q", "n"]}
# 我不要豬肉 其他都可以
# [u'我', u'不要', u'豬肉', u' ', u'其他', u'都', u'可以']
# {"term": ["我", "不要", "豬肉", " ", "其他", "都", "可以"], "pos": ["r", "ineg", "n", "x", "r", "d", "c"]}
# 我不吃豬，有甚麼可以吃的?
# [u'我', u'不吃', u'豬', u'，', u'有', u'甚麼', u'可以', u'吃', u'的', u'?']
# {"term": ["我", "不吃", "豬", "，", "有", "甚麼", "可以", "吃", "的", "?"], "pos": ["r", "v", "zg", "x", "v", "r", "c", "v", "uj", "x"]}
# 鼎泰豐的泡菜和一般市售的泡菜口味不同，請問是屬於何種口味?
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請', u'問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# {"term": ["鼎泰豐", "的", "泡菜", "和", "一般", "市售", "的", "泡菜", "口味", "不同", "，", "請", "問", "是", "屬", "於", "何種", "口味", "?"], "pos": ["inoun", "uj", "inoun", "c", "a", "v", "uj", "inoun", "n", "a", "x", "v", "v", "v", "v", "nr", "r", "n", "x"]}
# 你們的泡菜為什麼跟市面上的味道不太一樣
# [u'你們', u'的', u'泡菜', u'為', u'什麼', u'跟', u'市', u'面上', u'的', u'味道', u'不', u'太', u'一樣']
# {"term": ["你們", "的", "泡菜", "為", "什麼", "跟", "市", "面上", "的", "味道", "不", "太", "一樣"], "pos": ["r", "uj", "inoun", "p", "r", "p", "n", "f", "uj", "n", "d", "d", "u"]}
# 泡菜是怎麼做的?
# [u'泡菜', u'是', u'怎麼', u'做', u'的', u'?']
# {"term": ["泡菜", "是", "怎麼", "做", "的", "?"], "pos": ["inoun", "v", "r", "v", "uj", "x"]}
# 介紹一下你們的泡菜
# [u'介紹', u'一下', u'你們', u'的', u'泡菜']
# {"term": ["介紹", "一下", "你們", "的", "泡菜"], "pos": ["v", "m", "r", "uj", "inoun"]}
# 泡菜是你們自己做的嗎?
# [u'泡菜', u'是', u'你們', u'自己', u'做', u'的', u'嗎', u'?']
# {"term": ["泡菜", "是", "你們", "自己", "做", "的", "嗎", "?"], "pos": ["inoun", "v", "r", "r", "v", "uj", "y", "x"]}
# 鼎泰豐泡菜的味道跟一般不一樣，怎麼會這樣啊?
# [u'鼎泰豐', u'泡菜', u'的', u'味道', u'跟', u'一般', u'不一', u'樣', u'，', u'怎麼', u'會', u'這樣', u'啊', u'?']
# {"term": ["鼎泰豐", "泡菜", "的", "味道", "跟", "一般", "不一", "樣", "，", "怎麼", "會", "這樣", "啊", "?"], "pos": ["inoun", "inoun", "uj", "n", "p", "a", "c", "x", "x", "r", "v", "r", "y", "x"]}
# 你們泡菜是哪種口味
# [u'你們', u'泡菜', u'是', u'哪種', u'口味']
# {"term": ["你們", "泡菜", "是", "哪種", "口味"], "pos": ["r", "inoun", "v", "r", "n"]}
# 鼎泰豐的泡菜是什麼口味阿
# [u'鼎泰豐', u'的', u'泡菜', u'是', u'什麼', u'口味', u'阿']
# {"term": ["鼎泰豐", "的", "泡菜", "是", "什麼", "口味", "阿"], "pos": ["inoun", "uj", "inoun", "v", "r", "n", "j"]}
# 你們的泡菜是台式口味嗎?
# [u'你們', u'的', u'泡菜', u'是', u'台式', u'口味', u'嗎', u'?']
# {"term": ["你們", "的", "泡菜", "是", "台式", "口味", "嗎", "?"], "pos": ["r", "uj", "inoun", "v", "inoun", "n", "x", "x"]}
# 你們的泡菜是韓式還是台式泡菜阿?
# [u'你們', u'的', u'泡菜', u'是', u'韓式', u'還是', u'台式泡菜', u'阿', u'?']
# {"term": ["你們", "的", "泡菜", "是", "韓式", "還是", "台式泡菜", "阿", "?"], "pos": ["r", "uj", "inoun", "v", "inoun", "c", "inoun", "j", "x"]}
# 店內的酸辣湯材料有哪些?
# [u'店', u'內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# {"term": ["店", "內", "的", "酸辣湯", "材料", "有", "哪些", "?"], "pos": ["n", "f", "uj", "inoun", "n", "v", "r", "x"]}
# 酸辣湯有哪些食材
# [u'酸辣湯', u'有', u'哪些', u'食材']
# {"term": ["酸辣湯", "有", "哪些", "食材"], "pos": ["inoun", "v", "r", "n"]}
# 鼎泰豐的酸辣湯加了哪些東西
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# {"term": ["鼎泰豐", "的", "酸辣湯", "加", "了", "哪些", "東西"], "pos": ["inoun", "uj", "inoun", "v", "ul", "r", "ns"]}
# 酸辣湯裡面有什麼
# [u'酸辣湯', u'裡面', u'有', u'什麼']
# {"term": ["酸辣湯", "裡面", "有", "什麼"], "pos": ["inoun", "f", "v", "r"]}
# 酸辣湯看起來好豐富，裡面有哪些東西
# [u'酸辣湯', u'看起', u'來', u'好', u'豐富', u'，', u'裡面', u'有', u'哪些', u'東西']
# {"term": ["酸辣湯", "看起", "來", "好", "豐富", "，", "裡面", "有", "哪些", "東西"], "pos": ["inoun", "v", "v", "a", "a", "x", "f", "v", "r", "ns"]}
# 你們的酸辣湯放了哪些材料
# [u'你們', u'的', u'酸辣湯', u'放', u'了', u'哪些', u'材料']
# {"term": ["你們", "的", "酸辣湯", "放", "了", "哪些", "材料"], "pos": ["r", "uj", "inoun", "v", "ul", "r", "n"]}
# 酸辣湯的材料
# [u'酸辣湯', u'的', u'材料']
# {"term": ["酸辣湯", "的", "材料"], "pos": ["inoun", "uj", "n"]}
# 我想知道酸辣湯裡面有什麼食材
# [u'我', u'想', u'知道', u'酸辣湯', u'裡面', u'有', u'什麼', u'食材']
# {"term": ["我", "想", "知道", "酸辣湯", "裡面", "有", "什麼", "食材"], "pos": ["r", "v", "v", "inoun", "f", "v", "r", "n"]}
# 酸辣湯的內容物有哪些
# [u'酸辣湯', u'的', u'內容物', u'有', u'哪些']
# {"term": ["酸辣湯", "的", "內容物", "有", "哪些"], "pos": ["inoun", "uj", "n", "v", "r"]}
# 你們家的酸辣湯裡面都加了甚麼阿? 好好喝喔
# [u'你們', u'家', u'的', u'酸辣湯', u'裡面', u'都', u'加', u'了', u'甚麼', u'阿', u'?', u' ', u'好', u'好喝', u'喔']
# {"term": ["你們", "家", "的", "酸辣湯", "裡面", "都", "加", "了", "甚麼", "阿", "?", " ", "好", "好喝", "喔"], "pos": ["r", "q", "uj", "inoun", "f", "d", "v", "ul", "r", "n", "x", "x", "a", "v", "e"]}
# 店內有什麼是素食的食物?
# [u'店', u'內', u'有', u'什麼', u'是', u'素食', u'的', u'食物', u'?']
# {"term": ["店", "內", "有", "什麼", "是", "素食", "的", "食物", "?"], "pos": ["n", "f", "v", "r", "v", "inoun", "uj", "n", "x"]}
# 有素食的餐點嗎?
# [u'有', u'素食', u'的', u'餐點', u'嗎', u'?']
# {"term": ["有", "素食", "的", "餐點", "嗎", "?"], "pos": ["v", "inoun", "uj", "n", "y", "x"]}
# 我吃素，可以吃甚麼?
# [u'我', u'吃素', u'，', u'可以', u'吃', u'甚麼', u'?']
# {"term": ["我", "吃素", "，", "可以", "吃", "甚麼", "?"], "pos": ["r", "inoun", "x", "c", "v", "r", "x"]}
# 幫我列出素食的餐點
# [u'幫', u'我', u'列出', u'素食', u'的', u'餐點']
# {"term": ["幫", "我", "列出", "素食", "的", "餐點"], "pos": ["v", "r", "v", "inoun", "uj", "n"]}
# 素食有哪些
# [u'素食', u'有', u'哪些']
# {"term": ["素食", "有", "哪些"], "pos": ["inoun", "v", "r"]}
# 出家人可以吃甚麼
# [u'出家人', u'可以', u'吃', u'甚麼']
# {"term": ["出家人", "可以", "吃", "甚麼"], "pos": ["n", "c", "v", "r"]}
# 我今天不想吃肉，哪些是素的
# [u'我', u'今天', u'不想', u'吃', u'肉', u'，', u'哪些', u'是', u'素', u'的']
# {"term": ["我", "今天", "不想", "吃", "肉", "，", "哪些", "是", "素", "的"], "pos": ["r", "t", "ineg", "v", "n", "x", "r", "v", "n", "uj"]}
# 我媽吃素，有沒有推薦的餐點
# [u'我', u'媽', u'吃素', u'，', u'有', u'沒有', u'推薦', u'的', u'餐點']
# {"term": ["我", "媽", "吃素", "，", "有", "沒有", "推薦", "的", "餐點"], "pos": ["r", "n", "inoun", "x", "v", "v", "v", "uj", "n"]}
# 鼎泰豐有素的餐點嗎
# [u'鼎泰豐', u'有素', u'的', u'餐點', u'嗎']
# {"term": ["鼎泰豐", "有素", "的", "餐點", "嗎"], "pos": ["inoun", "n", "uj", "n", "y"]}
# 鼎泰豐 素食
# [u'鼎泰豐', u' ', u'素食']
# {"term": ["鼎泰豐", " ", "素食"], "pos": ["inoun", "x", "inoun"]}
# 鼎泰豐所使用的牛肉是哪裡的產地?
# [u'鼎泰豐', u'所', u'使用', u'的', u'牛肉', u'是', u'哪裡', u'的', u'產地', u'?']
# {"term": ["鼎泰豐", "所", "使用", "的", "牛肉", "是", "哪裡", "的", "產地", "?"], "pos": ["inoun", "c", "v", "uj", "n", "v", "r", "uj", "n", "x"]}
# 你們是用美國牛嗎?
# [u'你們', u'是', u'用', u'美國', u'牛', u'嗎', u'?']
# {"term": ["你們", "是", "用", "美國", "牛", "嗎", "?"], "pos": ["r", "v", "p", "ns", "n", "y", "x"]}
# 你們的牛肉是哪一國的牛?
# [u'你們', u'的', u'牛肉', u'是', u'哪一', u'國', u'的', u'牛', u'?']
# {"term": ["你們", "的", "牛肉", "是", "哪一", "國", "的", "牛", "?"], "pos": ["r", "uj", "n", "v", "r", "n", "uj", "n", "x"]}
# 我想知道你們用的是哪一國的牛肉
# [u'我', u'想', u'知道', u'你們', u'用', u'的', u'是', u'哪一', u'國', u'的', u'牛肉']
# {"term": ["我", "想", "知道", "你們", "用", "的", "是", "哪一", "國", "的", "牛肉"], "pos": ["r", "v", "v", "r", "p", "uj", "v", "r", "n", "uj", "n"]}
# 你們牛肉的來源是哪裡?
# [u'你們', u'牛肉', u'的', u'來源', u'是', u'哪裡', u'?']
# {"term": ["你們", "牛肉", "的", "來源", "是", "哪裡", "?"], "pos": ["r", "n", "uj", "n", "v", "r", "x"]}
# 牛肉 產地
# [u'牛肉', u' ', u'產地']
# {"term": ["牛肉", " ", "產地"], "pos": ["n", "x", "j"]}
# 你們使用的牛肉是美國來的嗎?
# [u'你們', u'使用', u'的', u'牛肉', u'是', u'美國', u'來的', u'嗎', u'?']
# {"term": ["你們", "使用", "的", "牛肉", "是", "美國", "來的", "嗎", "?"], "pos": ["r", "v", "uj", "n", "v", "ns", "u", "y", "x"]}
# 牛肉是台灣本土的嗎?
# [u'牛肉', u'是', u'台灣', u'本土', u'的', u'嗎', u'?']
# {"term": ["牛肉", "是", "台灣", "本土", "的", "嗎", "?"], "pos": ["n", "v", "ns", "n", "uj", "y", "x"]}
# 你們是進哪裡的牛肉?
# [u'你們', u'是', u'進', u'哪裡', u'的', u'牛肉', u'?']
# {"term": ["你們", "是", "進", "哪裡", "的", "牛肉", "?"], "pos": ["r", "v", "v", "r", "uj", "n", "x"]}
# 你們有沒有用美國牛?
# [u'你們', u'有', u'沒', u'有用', u'美國', u'牛', u'?']
# {"term": ["你們", "有", "沒", "有用", "美國", "牛", "?"], "pos": ["r", "v", "v", "v", "ns", "n", "x"]}
# 是否會含有瘦肉精?
# [u'是否', u'會', u'含有', u'瘦肉精', u'?']
# {"term": ["是否", "會", "含有", "瘦肉精", "?"], "pos": ["v", "zg", "v", "nz", "x"]}
# 你們的牛肉有沒有瘦肉精?
# [u'你們', u'的', u'牛肉', u'有', u'沒有', u'瘦肉精', u'?']
# {"term": ["你們", "的", "牛肉", "有", "沒有", "瘦肉精", "?"], "pos": ["r", "uj", "n", "v", "v", "nz", "x"]}
# 你們的牛肉會不會有含瘦肉精但你們不知道?
# [u'你們', u'的', u'牛肉', u'會', u'不', u'會', u'有', u'含', u'瘦肉精', u'但', u'你們', u'不知', u'道', u'?']
# {"term": ["你們", "的", "牛肉", "會", "不", "會", "有", "含", "瘦肉精", "但", "你們", "不知", "道", "?"], "pos": ["r", "uj", "n", "v", "d", "v", "v", "v", "nz", "c", "r", "v", "q", "x"]}
# 老實說，你們的餐點有沒有瘦肉精?
# [u'老實', u'說', u'，', u'你們', u'的', u'餐點', u'有', u'沒有', u'瘦肉精', u'?']
# {"term": ["老實", "說", "，", "你們", "的", "餐點", "有", "沒有", "瘦肉精", "?"], "pos": ["n", "v", "x", "r", "uj", "n", "v", "v", "nz", "x"]}
# 鼎泰豐的東西有瘦肉精嗎?
# [u'鼎泰豐', u'的', u'東西', u'有', u'瘦肉精', u'嗎', u'?']
# {"term": ["鼎泰豐", "的", "東西", "有", "瘦肉精", "嗎", "?"], "pos": ["inoun", "uj", "ns", "v", "nz", "x", "x"]}
# 你們的食材裡會含有瘦肉精嗎?
# [u'你們', u'的', u'食材', u'裡', u'會', u'含有', u'瘦肉精', u'嗎', u'?']
# {"term": ["你們", "的", "食材", "裡", "會", "含有", "瘦肉精", "嗎", "?"], "pos": ["r", "uj", "n", "f", "v", "v", "nz", "x", "x"]}
# 該不會你們食物有瘦肉精吧
# [u'該', u'不', u'會', u'你們', u'食物', u'有', u'瘦肉精', u'吧']
# {"term": ["該", "不", "會", "你們", "食物", "有", "瘦肉精", "吧"], "pos": ["r", "d", "v", "r", "n", "v", "nz", "y"]}
# 還是問一下好了，你們的肉類有沒有瘦肉精阿?
# [u'還是', u'問', u'一下', u'好', u'了', u'，', u'你們', u'的', u'肉類', u'有', u'沒有', u'瘦肉精', u'阿', u'?']
# {"term": ["還是", "問", "一下", "好", "了", "，", "你們", "的", "肉類", "有", "沒有", "瘦肉精", "阿", "?"], "pos": ["c", "v", "m", "a", "ul", "x", "r", "uj", "n", "v", "v", "nz", "j", "x"]}
# 你們的肉類有驗過瘦肉精嗎
# [u'你們', u'的', u'肉類', u'有驗', u'過', u'瘦肉精', u'嗎']
# {"term": ["你們", "的", "肉類", "有驗", "過", "瘦肉精", "嗎"], "pos": ["r", "uj", "n", "vn", "ug", "nz", "x"]}
# 鼎泰豐的肉品有沒有瘦肉精阿?
# [u'鼎泰豐', u'的', u'肉品', u'有', u'沒有', u'瘦肉精', u'阿', u'?']
# {"term": ["鼎泰豐", "的", "肉品", "有", "沒有", "瘦肉精", "阿", "?"], "pos": ["inoun", "uj", "n", "v", "v", "nz", "j", "x"]}
# 是否有廠商產地證明或檢驗證明文件?
# [u'是否', u'有廠', u'商產地', u'證明', u'或', u'檢驗', u'證明', u'文件', u'?']
# {"term": ["是否", "有廠", "商產地", "證明", "或", "檢驗", "證明", "文件", "?"], "pos": ["v", "n", "n", "n", "c", "vn", "n", "n", "x"]}
# 餐點有檢驗報告嗎
# [u'餐點', u'有', u'檢驗', u'報告', u'嗎']
# {"term": ["餐點", "有", "檢驗", "報告", "嗎"], "pos": ["n", "v", "vn", "n", "y"]}
# 餐點都有送驗嗎?
# [u'餐點', u'都', u'有', u'送驗', u'嗎', u'?']
# {"term": ["餐點", "都", "有", "送驗", "嗎", "?"], "pos": ["n", "d", "v", "v", "y", "x"]}
# 你們的供貨商有檢驗證明文件嗎?
# [u'你們', u'的', u'供貨', u'商有', u'檢驗', u'證明', u'文件', u'嗎', u'?']
# {"term": ["你們", "的", "供貨", "商有", "檢驗", "證明", "文件", "嗎", "?"], "pos": ["r", "uj", "n", "v", "vn", "n", "n", "x", "x"]}
# 鼎泰豐的食材有檢驗過嗎?
# [u'鼎泰豐', u'的', u'食材', u'有', u'檢驗', u'過', u'嗎', u'?']
# {"term": ["鼎泰豐", "的", "食材", "有", "檢驗", "過", "嗎", "?"], "pos": ["inoun", "uj", "n", "v", "vn", "ug", "y", "x"]}
# 你們的東西安全嗎? 有驗過嗎?
# [u'你們', u'的', u'東西', u'安全', u'嗎', u'?', u' ', u'有驗', u'過', u'嗎', u'?']
# {"term": ["你們", "的", "東西", "安全", "嗎", "?", " ", "有驗", "過", "嗎", "?"], "pos": ["r", "uj", "ns", "an", "x", "x", "x", "vn", "ug", "y", "x"]}
# 最近食安問題很多，你們怎麼證明自家的東西是安全的?
# [u'最近', u'食安', u'問題', u'很多', u'，', u'你們', u'怎麼', u'證明', u'自家', u'的', u'東西', u'是', u'安全', u'的', u'?']
# {"term": ["最近", "食安", "問題", "很多", "，", "你們", "怎麼", "證明", "自家", "的", "東西", "是", "安全", "的", "?"], "pos": ["f", "n", "n", "m", "x", "r", "r", "v", "r", "uj", "ns", "v", "an", "uj", "x"]}
# 你們的食材有產地證明嗎?
# [u'你們', u'的', u'食材', u'有', u'產地證', u'明', u'嗎', u'?']
# {"term": ["你們", "的", "食材", "有", "產地證", "明", "嗎", "?"], "pos": ["r", "uj", "n", "v", "j", "a", "y", "x"]}
# 鼎泰豐的供應商有提供證明文件嗎?
# [u'鼎泰豐', u'的', u'供應', u'商有', u'提供', u'證明', u'文件', u'嗎', u'?']
# {"term": ["鼎泰豐", "的", "供應", "商有", "提供", "證明", "文件", "嗎", "?"], "pos": ["inoun", "uj", "vn", "v", "v", "n", "n", "x", "x"]}
# 你們有哪些證明或檢驗文件呢?
# [u'你們', u'有', u'哪些', u'證明', u'或', u'檢驗', u'文件', u'呢', u'?']
# {"term": ["你們", "有", "哪些", "證明", "或", "檢驗", "文件", "呢", "?"], "pos": ["r", "v", "r", "n", "c", "vn", "n", "y", "x"]}

# %%
######### output
DTFQA.to_pickle('./db/DTFQA_v03')

# %%
######### verify output data
DTFQA = pd.read_pickle('./db/DTFQA_v03')
DTFQA.iloc[0:5,:]
# Out:
#   No.  utterances intent         entity     nlp_class nlp_name  \
# 0   1    請問洗手間在哪?    問門市  分店::內部資訊,洗手間;  NLP_Major_05     店內資訊
# 1   1   你們化妝室怎麼走?    問門市  分店::內部資訊,化妝室;  NLP_Major_05     店內資訊
# 2   1       我想上廁所    問門市   分店::內部資訊,廁所;  NLP_Major_05     店內資訊
# 3   3  什麼時候不需要排隊?    問門市     分店::候位,排隊;  NLP_Major_05     店內資訊
# 4   3      哪時候人最少    問門市    分店::候位,人最少;  NLP_Major_05     店內資訊
#
#                      term                    pos
# 0  [請, 問, 洗手, 間, 在, 哪, ?]  [v, v, v, f, p, r, x]
# 1     [你們, 化妝室, 怎麼, 走, ?]        [r, n, r, v, x]
# 2           [我, 想, 上, 廁所]           [r, v, f, n]
# 3  [什麼, 時候, 不, 需要, 排隊, ?]     [r, n, d, v, n, x]
# 4            [哪時候, 人, 最少]              [r, n, d]

# %%
###########################################################################
#######################  以下都是測試程式 ##################################

# %%
print jeba.ret_json

# %%
j_format = json.loads(jeba.ret_json)
print repr(j_format['term']).decode("unicode-escape")

# %%
DTFQA
