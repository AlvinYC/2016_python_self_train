# %%
#encoding utf-8
import numpy as np
import pandas as pd
import re
import itertools
from IPython.display import Image

# %%
DTFQA = pd.read_pickle('../01_Chat_Identfier/db/DTFQA_v03')
print len(DTFQA)
DTFQA.iloc[0:5,:]
# Out:
# 130
#   No.  utterances intent         entity     nlp_class nlp_name  \
# 0   1    請問洗手間在哪?    問門市  分店::內部資訊,洗手間;  NLP_Major_05     店內資訊
# 1   1   你們化妝室怎麼走?    問門市  分店::內部資訊,化妝室;  NLP_Major_05     店內資訊
# 2   1       我想上廁所    問門市   分店::內部資訊,廁所;  NLP_Major_05     店內資訊
# 3   3  什麼時候不需要排隊?    問門市     分店::候位,排隊;  NLP_Major_05     店內資訊
# 4   3      哪時候人最少    問門市    分店::候位,人最少;  NLP_Major_05     店內資訊
#
#                  term                                  pos
# 0    [請問, 洗手間, 在哪, ?]  [qhead, branchinnerinfob, where, x]
# 1   [你們, 化妝室, 怎麼走, ?]     [nh, branchinnerinfob, where, x]
# 2       [我, 想, 上, 廁所]          [r, v, f, branchinnerinfob]
# 3  [什麼時候, 不需要, 排隊, ?]    [when, ineg, branchinnerinfoa, x]
# 4          [哪時候, 人最少]             [when, branchinnerinfoa]

# %%
DTFQA_STATISTIC = pd.read_pickle('../01_Chat_Identfier/db/DTFQA_STATISTIC')
print len(DTFQA_STATISTIC)
DTFQA_STATISTIC.iloc[0:5,:]
# Out:
# 931
#                 pos term
# 0             qhead   請問
# 1  branchinnerinfob  洗手間
# 2             where   在哪
# 3                 x    ?
# 4                nh   你們

# %%
#取得所有 term 的所有可能 (移除重複)
POS_DETAIL = pd.DataFrame({'count' : DTFQA_STATISTIC.groupby( [ "pos", "term"] ).size()}).reset_index()
POS_DETAIL.iloc[0:10,:]
print 'all kind of term == ' + str(len(POS_DETAIL))
# Out:
# all kind of term == 256

# %%
POS_DETAIL.iloc[0:10,:]

# %%
def check_pos_pair_in_DTFQA(p1,p2):
    ret = 'FALSE'
    for idx in range(len(DTFQA)):
        fork_sentence_term = list(np.array(DTFQA['term'][idx]))
        fork_sentence_pos  = list(np.array(DTFQA['pos'][idx]))
        #print repr(DTFQA['term'][idx]).decode('unicode-escape')
        
        if p1 in fork_sentence_pos:
            p1_index = fork_sentence_pos.index(p1)
            fork_sentence_pos.remove(p1)
            del fork_sentence_term[p1_index]
            #print 'match pos'
            #print repr(fork_sentence_pos).decode('unicode-escape')
            #print repr(fork_sentence_term).decode('unicode-escape')
        if p2 in fork_sentence_term:
            fork_sentence_term.remove(p2)
            #print 'match term'
            #print repr(fork_sentence_term).decode('unicode-escape')
        if len(DTFQA['term'][idx]) == len(fork_sentence_term) + 2:
            print repr(DTFQA['term'][idx]).decode('unicode-escape')
            #print 'orig_len = ' + str(len(DTFQA['term'][idx])) + ', after removement =' + str(len(fork_sentence_term))
            return 'TRUE'
    return ret

# %%
p1 = u'dtfappetizer'
p2 = u'泡菜'
ret = check_pos_pair_in_DTFQA(p1,p2)
print ret
# Out:
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# TRUE

# %%
pd.set_option("display.max_rows",100)
# DTF要處理的 n 集合
idx = np.array([bool(re.search(u'branch.*|^n$|dtf.*|ingredient', element)) for element in POS_DETAIL['pos']])
#idx = np.array([bool(re.search(u'^n$', element)) for element in POS_DETAIL['pos']])
print len(POS_DETAIL.iloc[idx,:])
DTF_N_SET = POS_DETAIL.iloc[idx,0:2]
DTF_N_SET
# Out:
# 62
#                   pos    term
# 3    branchinnerinfoa     人最少
# 4    branchinnerinfoa      候位
# 5    branchinnerinfoa      排隊
# 6    branchinnerinfob     化妝室
# 7    branchinnerinfob      廁所
# 8    branchinnerinfob     洗手間
# 44       dtfappetizer      泡菜
# 45          dtfbranch     信義店
# 46     dtfbranchkinda     其他店
# 47     dtfbranchkinda    台灣門市
# 48     dtfbranchkinda   國外的分店
# 49     dtfbranchkinda    國外門市
# 50     dtfbranchkinda      店內
# 51     dtfbranchkinda    海外分店
# 52     dtfbranchkindb    港式餐廳
# 53     dtfbranchkindb    港式點心
# 54           dtfbrand     鼎泰豐
# 55           dtfdrink       茶
# 56           dtfdrink      茶葉
# 57        dtffoodkind      台式
# 58        dtffoodkind      吃素
# 59        dtffoodkind      吃肉
# 60        dtffoodkind      素的
# 61        dtffoodkind      素食
# 62        dtffoodkind      韓式
# 63      dtffoodsaftya    檢驗報告
# 64      dtffoodsaftya    檢驗文件
# 65      dtffoodsaftya  檢驗證明文件
# 66      dtffoodsaftya     檢驗過
# 67      dtffoodsaftya    產地證明
# 68      dtffoodsaftya      證明
# 69      dtffoodsaftya    證明文件
# 70      dtffoodsaftya      送驗
# 71      dtffoodsaftya      驗過
# 72      dtffoodsaftyb     瘦肉精
# 73      dtffoodsaftyb    食安問題
# 74        dtffoodtype      蒸的
# 75        dtffoodtype     蒸籠類
# 76      dtfingredient      牛肉
# 77      dtfingredient     美國牛
# 78      dtfingredient      肉品
# 79      dtfingredient      肉類
# 80      dtfingredient       豬
# 81      dtfingredient      豬肉
# 82            dtfsoup     酸辣湯
# 83     dtfxiaolongbao     小籠包
# 84     dtfxiaolongbao    小籠湯包
# 113        ingredient     內容物
# 114        ingredient     有什麼
# 115        ingredient      材料
# 116        ingredient      東西
# 117        ingredient      食材
# 129                 n      問題
# 130                 n      因素
# 131                 n       媽
# 132                 n      宗教
# 133                 n       市
# 134                 n       牛
# 135                 n      老實
# 136                 n       茶
# 137                 n       豬
# 138                 n      面包

# %%
# all kind of (N,N) pair, 不只是同一句有出現
# 62*62 = 3844 --> 1020
ALL_NN_PAIR = list(set(list(itertools.product(DTF_N_SET['pos'], DTF_N_SET['term']))))
DTF_NN_PAIR = []
print len(ALL_NN_PAIR)
for (p1, p2) in ALL_NN_PAIR: 
    #print repr(p1).decode('unicode-escape') + ',' + repr(p2).decode('unicode-escape')
    ret = check_pos_pair_in_DTFQA(p1,p2)
    if ret == 'TRUE':
        print repr(p1).decode('unicode-escape') + ',' + repr(p2).decode('unicode-escape')
        DTF_NN_PAIR.append([p1,p2])
print len(DTF_NN_PAIR)
# Out:
# 1020
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# u'dtfsoup',u'鼎泰豐'
# [u'鼎泰豐', u'賣', u'的', u'是', u'港式點心', u'嗎', u'?']
# u'dtfbranchkindb',u'鼎泰豐'
# [u'請問', u'那些', u'東西', u'沒有', u'豬肉']
# u'ingredient',u'豬肉'
# [u'店內', u'有什麼', u'是', u'素食', u'的', u'食物', u'?']
# u'dtffoodkind',u'店內'
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# u'dtfbrand',u'泡菜'
# [u'你們', u'的', u'肉類', u'有', u'驗過', u'瘦肉精', u'嗎']
# u'dtffoodsaftya',u'瘦肉精'
# [u'我', u'今天', u'不想', u'吃肉', u'，', u'哪些', u'是', u'素的']
# u'dtffoodkind',u'素的'
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# u'dtfappetizer',u'鼎泰豐'
# [u'鼎泰豐', u'的', u'東西', u'有', u'瘦肉精', u'嗎', u'?']
# u'dtffoodsaftyb',u'東西'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'dtfingredient',u'宗教'
# [u'你們', u'的', u'東西', u'安全', u'嗎', u'?', u' ', u'有', u'驗過', u'嗎', u'?']
# u'ingredient',u'驗過'
# [u'鼎泰豐', u'的', u'食材', u'有', u'檢驗過', u'嗎', u'?']
# u'ingredient',u'檢驗過'
# [u'你們', u'的', u'泡菜', u'為什麼', u'跟', u'市', u'面上', u'的', u'味道', u'不太一樣']
# u'n',u'泡菜'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'n',u'蒸的'
# [u'除了', u'信義店', u'外', u'，', u'還', u'有', u'其他店', u'不能', u'刷卡', u'嗎', u'?']
# u'dtfbranchkinda',u'信義店'
# [u'你們', u'的', u'食材', u'有', u'產地證明', u'嗎', u'?']
# u'ingredient',u'產地證明'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'ingredient',u'豬'
# [u'你們', u'的', u'食材', u'裡', u'會', u'含有', u'瘦肉精', u'嗎', u'?']
# u'dtffoodsaftyb',u'食材'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'ingredient',u'蒸的'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'dtffoodtype',u'宗教'
# [u'你們', u'的', u'牛肉', u'是', u'哪一國', u'的', u'牛', u'?']
# u'dtfingredient',u'牛'
# [u'鼎泰豐', u'有', u'素的', u'餐點', u'嗎']
# u'dtffoodkind',u'鼎泰豐'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'dtffoodtype',u'因素'
# [u'信義店', u'為何', u'沒有', u'提供', u'信用卡刷卡', u'服務', u'的', u'問題', u'?']
# u'dtfbranch',u'問題'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'dtffoodtype',u'豬肉'
# [u'你們', u'的', u'東西', u'安全', u'嗎', u'?', u' ', u'有', u'驗過', u'嗎', u'?']
# u'dtffoodsaftya',u'東西'
# [u'我', u'媽', u'吃素', u'，', u'有沒有', u'推薦', u'的', u'餐點']
# u'dtffoodkind',u'媽'
# [u'還是', u'問', u'一下', u'好', u'了', u'，', u'你們', u'的', u'肉類', u'有沒有', u'瘦肉精', u'阿', u'?']
# u'dtffoodsaftyb',u'肉類'
# [u'你們', u'的', u'牛肉', u'是', u'哪一國', u'的', u'牛', u'?']
# u'n',u'牛肉'
# [u'你們', u'的', u'肉類', u'有', u'驗過', u'瘦肉精', u'嗎']
# u'dtffoodsaftya',u'肉類'
# [u'國外門市', u'賣', u'的', u'東西', u'會', u'比較', u'多樣', u'嗎', u'?']
# u'dtfbranchkinda',u'東西'
# [u'小籠包', u'裡', u'面包', u'了', u'甚麼']
# u'n',u'小籠包'
# [u'鼎泰豐', u'的', u'食材', u'有', u'檢驗過', u'嗎', u'?']
# u'dtfbrand',u'檢驗過'
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# u'dtfbrand',u'酸辣湯'
# [u'鼎泰豐', u'是', u'港式餐廳', u'嗎', u'?']
# u'dtfbrand',u'港式餐廳'
# [u'你們', u'的', u'牛肉', u'有沒有', u'瘦肉精', u'?']
# u'dtfingredient',u'瘦肉精'
# [u'小籠包', u'裡', u'面包', u'了', u'甚麼']
# u'dtfxiaolongbao',u'面包'
# [u'最近', u'食安問題', u'很多', u'，', u'你們', u'怎麼', u'證明', u'自家', u'的', u'東西', u'是', u'安全', u'的', u'?']
# u'ingredient',u'證明'
# [u'鼎泰豐', u'的', u'東西', u'有', u'瘦肉精', u'嗎', u'?']
# u'ingredient',u'瘦肉精'
# [u'鼎泰豐', u'的', u'食材', u'有', u'檢驗過', u'嗎', u'?']
# u'dtffoodsaftya',u'食材'
# [u'信義店', u'為何', u'沒有', u'提供', u'信用卡刷卡', u'服務', u'的', u'問題', u'?']
# u'n',u'信義店'
# [u'最近', u'食安問題', u'很多', u'，', u'你們', u'怎麼', u'證明', u'自家', u'的', u'東西', u'是', u'安全', u'的', u'?']
# u'ingredient',u'食安問題'
# [u'你們', u'的', u'茶', u'是', u'什麼', u'茶', u'?']
# u'dtfdrink',u'茶'
# [u'店內', u'有什麼', u'是', u'素食', u'的', u'食物', u'?']
# u'dtfbranchkinda',u'有什麼'
# [u'我', u'媽', u'吃素', u'，', u'有沒有', u'推薦', u'的', u'餐點']
# u'n',u'吃素'
# [u'店內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# u'dtfsoup',u'材料'
# [u'店內', u'客人', u'喝', u'的', u'是', u'甚麼', u'茶', u'?']
# u'dtfbranchkinda',u'茶'
# [u'店內', u'有什麼', u'是', u'素食', u'的', u'食物', u'?']
# u'dtffoodkind',u'有什麼'
# [u'請問', u'那些', u'東西', u'沒有', u'豬肉']
# u'dtfingredient',u'東西'
# [u'鼎泰豐', u'所', u'使用', u'的', u'牛肉', u'是', u'哪裡', u'的', u'產地', u'?']
# u'dtfbrand',u'牛肉'
# [u'你們', u'的', u'茶', u'是', u'哪種', u'茶葉', u'?']
# u'n',u'茶葉'
# [u'小籠湯包', u'與', u'小籠包', u'有什麼', u'不同', u'?']
# u'ingredient',u'小籠包'
# [u'你們', u'的', u'肉類', u'有', u'驗過', u'瘦肉精', u'嗎']
# u'dtffoodsaftyb',u'驗過'
# [u'鼎泰豐', u'的', u'食材', u'有', u'檢驗過', u'嗎', u'?']
# u'dtfbrand',u'食材'
# [u'國外門市', u'賣', u'的', u'東西', u'會', u'比較', u'多樣', u'嗎', u'?']
# u'ingredient',u'國外門市'
# [u'最近', u'食安問題', u'很多', u'，', u'你們', u'怎麼', u'證明', u'自家', u'的', u'東西', u'是', u'安全', u'的', u'?']
# u'dtffoodsaftya',u'食安問題'
# [u'老實', u'說', u'，', u'你們', u'的', u'餐點', u'有沒有', u'瘦肉精', u'?']
# u'dtffoodsaftyb',u'老實'
# [u'鼎泰豐', u'的', u'東西', u'有', u'瘦肉精', u'嗎', u'?']
# u'dtffoodsaftyb',u'鼎泰豐'
# [u'鼎泰豐', u'的', u'東西', u'有', u'瘦肉精', u'嗎', u'?']
# u'dtfbrand',u'瘦肉精'
# [u'海外分店', u'餐點', u'和', u'台灣門市', u'餐點', u'的', u'不同', u'?']
# u'dtfbranchkinda',u'台灣門市'
# [u'你們', u'的', u'茶', u'是', u'什麼', u'茶', u'?']
# u'n',u'茶'
# [u'店內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# u'dtfbranchkinda',u'材料'
# [u'除了', u'信義店', u'外', u'，', u'還', u'有', u'其他店', u'不能', u'刷卡', u'嗎', u'?']
# u'dtfbranch',u'其他店'
# [u'店內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# u'dtfsoup',u'店內'
# [u'你們', u'的', u'泡菜', u'為什麼', u'跟', u'市', u'面上', u'的', u'味道', u'不太一樣']
# u'dtfappetizer',u'市'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'dtffoodtype',u'東西'
# [u'你們', u'的', u'泡菜', u'是', u'韓式', u'還是', u'台式', u'泡菜', u'阿', u'?']
# u'dtffoodkind',u'台式'
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# u'dtfappetizer',u'泡菜'
# [u'老實', u'說', u'，', u'你們', u'的', u'餐點', u'有沒有', u'瘦肉精', u'?']
# u'n',u'瘦肉精'
# [u'最近', u'食安問題', u'很多', u'，', u'你們', u'怎麼', u'證明', u'自家', u'的', u'東西', u'是', u'安全', u'的', u'?']
# u'dtffoodsaftyb',u'證明'
# [u'小籠湯包', u'與', u'小籠包', u'有什麼', u'不同', u'?']
# u'dtfxiaolongbao',u'小籠包'
# [u'你們', u'的', u'牛肉', u'有沒有', u'瘦肉精', u'?']
# u'dtffoodsaftyb',u'牛肉'
# [u'鼎泰豐', u'的', u'供應商', u'有', u'提供', u'證明文件', u'嗎', u'?']
# u'dtfbrand',u'證明文件'
# [u'店內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# u'dtfbranchkinda',u'酸辣湯'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'n',u'東西'
# [u'鼎泰豐', u'賣', u'的', u'是', u'港式點心', u'嗎', u'?']
# u'dtfbrand',u'港式點心'
# [u'是否', u'有', u'廠商', u'產地證明', u'或', u'檢驗證明文件', u'?']
# u'dtffoodsaftya',u'檢驗證明文件'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'dtffoodtype',u'豬'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'dtfingredient',u'蒸籠類'
# [u'酸辣湯', u'有', u'哪些', u'食材']
# u'dtfsoup',u'食材'
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# u'dtfsoup',u'東西'
# [u'鼎泰豐', u'有', u'素的', u'餐點', u'嗎']
# u'dtfbrand',u'素的'
# [u'鼎泰豐', u'的', u'肉品', u'有沒有', u'瘦肉精', u'阿', u'?']
# u'dtfbrand',u'肉品'
# [u'鼎泰豐', u' ', u'素食']
# u'dtfbrand',u'素食'
# [u'鼎泰豐', u'所', u'使用', u'的', u'牛肉', u'是', u'哪裡', u'的', u'產地', u'?']
# u'dtfingredient',u'鼎泰豐'
# [u'我', u'想', u'知道', u'酸辣湯', u'裡面', u'有什麼', u'食材']
# u'ingredient',u'食材'
# [u'店內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# u'ingredient',u'店內'
# [u'店內', u'有什麼', u'是', u'素食', u'的', u'食物', u'?']
# u'ingredient',u'素食'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'dtfingredient',u'因素'
# [u'你們', u'的', u'泡菜', u'是', u'台式', u'口味', u'嗎', u'?']
# u'dtffoodkind',u'泡菜'
# [u'你們', u'的', u'泡菜', u'是', u'台式', u'口味', u'嗎', u'?']
# u'dtfappetizer',u'台式'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'dtfingredient',u'豬肉'
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# u'ingredient',u'鼎泰豐'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'n',u'蒸籠類'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'n',u'因素'
# [u'鼎泰豐', u'的', u'肉品', u'有沒有', u'瘦肉精', u'阿', u'?']
# u'dtffoodsaftyb',u'肉品'
# [u'小籠湯包', u'與', u'小籠包', u'有什麼', u'不同', u'?']
# u'ingredient',u'小籠湯包'
# [u'鼎泰豐', u'的', u'食材', u'有', u'檢驗過', u'嗎', u'?']
# u'dtffoodsaftya',u'鼎泰豐'
# [u'店內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# u'ingredient',u'酸辣湯'
# [u'店內', u'客人', u'喝', u'的', u'是', u'甚麼', u'茶', u'?']
# u'dtfdrink',u'店內'
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# u'dtfbrand',u'東西'
# [u'小籠湯包', u'與', u'小籠包', u'有什麼', u'不同', u'?']
# u'dtfxiaolongbao',u'有什麼'
# [u'你們', u'的', u'泡菜', u'是', u'韓式', u'還是', u'台式', u'泡菜', u'阿', u'?']
# u'dtfappetizer',u'韓式'
# [u'你們', u'有', u'哪些', u'證明', u'或', u'檢驗文件', u'呢', u'?']
# u'dtffoodsaftya',u'檢驗文件'
# [u'店內', u'有什麼', u'是', u'素食', u'的', u'食物', u'?']
# u'dtfbranchkinda',u'素食'
# [u'酸辣湯', u'的', u'內容物', u'有', u'哪些']
# u'dtfsoup',u'內容物'
# [u'你們', u'的', u'肉類', u'有', u'驗過', u'瘦肉精', u'嗎']
# u'dtfingredient',u'驗過'
# [u'因為', u'宗教', u'因素', u'不吃', u'豬肉', u'，', u'請問', u'蒸籠類', u'鹹', u'的', u'哪些', u'不含', u'豬肉', u'？']
# u'n',u'豬肉'
# [u'酸辣湯', u'裡面', u'有什麼']
# u'dtfsoup',u'有什麼'
# 109

# %%
# SAVE TO dataframe
NN_NUMPY=np.array(DTF_NN_PAIR)
NN_POS_PAIR = pd.DataFrame(NN_NUMPY)
NN_POS_PAIR.columns = ['NPOS','NTERM']
NN_POS_PAIR.to_pickle('./NN_POS_PAIR')

# %%
# DTF要處理的 v 集合
idx = np.array([bool(re.search(u'^v$|^vg$', element)) for element in POS_DETAIL['pos']])
print len(POS_DETAIL.iloc[idx,:])
DTF_V_SET = POS_DETAIL.iloc[idx,:]
DTF_V_SET
# Out:
# 34
#     pos term  count
# 185   v   介紹      3
# 186   v   使用      2
# 187   v    來      3
# 188   v    做      1
# 189   v   列出      3
# 190   v    加      3
# 191   v    受      1
# 192   v   只能      2
# 193   v    吃      7
# 194   v    含      1
# 195   v   含有      2
# 196   v   告訴      1
# 197   v    問      2
# 198   v   好像      1
# 199   v    屬      1
# 200   v   市售      1
# 201   v    幫      4
# 202   v    想      8
# 203   v   挑選      1
# 204   v    收      1
# 205   v    放      1
# 206   v    是     12
# 207   v    會      4
# 208   v    有      7
# 209   v   發現      1
# 210   v   看起      1
# 211   v   知道      4
# 212   v    算      1
# 213   v    要      1
# 214   v    說      1
# 215   v    賣      3
# 216   v   起來      1
# 217   v    進      1
# 218  vg    喝      1

# %%
# all kind of (V,N) pair, 不只是同一句有出現
# 62 * 34 = 2108 -> 578
#ALL_NV_PAIR = list(set(list(itertools.product(DTF_N_SET['pos'], DTF_V_SET['term']))))
# 17 * 34 = 2108 -> 578
ALL_NV_PAIR = list(itertools.product(set(DTF_N_SET['pos']), DTF_V_SET['term']))
DTF_NV_PAIR = []
print len(list(ALL_NV_PAIR))
for (p1, p2) in ALL_NV_PAIR: 
    #print repr(p1).decode('unicode-escape') + ',' + repr(p2).decode('unicode-escape')
    ret = check_pos_pair_in_DTFQA(p1,p2)
    if ret == 'TRUE':
        print repr(p1).decode('unicode-escape') + ',' + repr(p2).decode('unicode-escape')
        DTF_NV_PAIR.append([p1,p2])
#print repr(DTF_NV_PAIR).decode('unicode-escape')
# Out:
# 578
# [u'酸辣湯', u'看起', u'來', u'好', u'豐富', u'，', u'裡面', u'有', u'哪些', u'東西']
# u'ingredient',u'來'
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# u'ingredient',u'加'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'ingredient',u'吃'
# [u'你們', u'的', u'食材', u'裡', u'會', u'含有', u'瘦肉精', u'嗎', u'?']
# u'ingredient',u'含有'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'ingredient',u'想'
# [u'你們', u'的', u'酸辣湯', u'放', u'了', u'哪些', u'材料']
# u'ingredient',u'放'
# [u'店內', u'有什麼', u'是', u'素食', u'的', u'食物', u'?']
# u'ingredient',u'是'
# [u'國外門市', u'賣', u'的', u'東西', u'會', u'比較', u'多樣', u'嗎', u'?']
# u'ingredient',u'會'
# [u'店內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# u'ingredient',u'有'
# [u'酸辣湯', u'看起', u'來', u'好', u'豐富', u'，', u'裡面', u'有', u'哪些', u'東西']
# u'ingredient',u'看起'
# [u'我', u'想', u'知道', u'酸辣湯', u'裡面', u'有什麼', u'食材']
# u'ingredient',u'知道'
# [u'國外門市', u'賣', u'的', u'東西', u'會', u'比較', u'多樣', u'嗎', u'?']
# u'ingredient',u'賣'
# [u'幫', u'我', u'介紹', u'一下', u'小籠湯包', u'和', u'小籠包', u'差別']
# u'dtfxiaolongbao',u'介紹'
# [u'小籠包', u'的', u'湯汁', u'是', u'怎麼', u'來', u'的']
# u'dtfxiaolongbao',u'來'
# [u'小籠包', u'加', u'了', u'甚麼', u'，', u'為什麼', u'湯汁', u'就是', u'比', u'別人', u'多']
# u'dtfxiaolongbao',u'加'
# [u'小籠包', u'為什麼', u'吃', u'起來', u'這麼多', u'汁', u'?']
# u'dtfxiaolongbao',u'吃'
# [u'我', u'想', u'問', u'一下', u'小籠包', u'為什麼', u'這麼多', u'汁', u'?']
# u'dtfxiaolongbao',u'問'
# [u'幫', u'我', u'介紹', u'一下', u'小籠湯包', u'和', u'小籠包', u'差別']
# u'dtfxiaolongbao',u'幫'
# [u'我', u'想', u'問', u'一下', u'小籠包', u'為什麼', u'這麼多', u'汁', u'?']
# u'dtfxiaolongbao',u'想'
# [u'小籠包', u'這麼多', u'汁', u'是', u'有', u'甚麼', u'獨門秘方', u'嗎', u'?']
# u'dtfxiaolongbao',u'是'
# [u'為什麼', u'小籠包', u'的', u'湯汁', u'會', u'這麼多', u'?']
# u'dtfxiaolongbao',u'會'
# [u'小籠包', u'這麼多', u'汁', u'是', u'有', u'甚麼', u'獨門秘方', u'嗎', u'?']
# u'dtfxiaolongbao',u'有'
# [u'小籠包', u'為什麼', u'吃', u'起來', u'這麼多', u'汁', u'?']
# u'dtfxiaolongbao',u'起來'
# [u'我', u'想', u'知道', u'你們', u'的', u'茶', u'是', u'用', u'甚麼', u'茶葉']
# u'dtfdrink',u'想'
# [u'你們', u'的', u'茶', u'是', u'什麼', u'茶', u'?']
# u'dtfdrink',u'是'
# [u'我', u'想', u'知道', u'你們', u'的', u'茶', u'是', u'用', u'甚麼', u'茶葉']
# u'dtfdrink',u'知道'
# [u'店內', u'客人', u'喝', u'的', u'是', u'甚麼', u'茶', u'?']
# u'dtfdrink',u'喝'
# [u'幫', u'我', u'列出', u'除了', u'有', u'豬肉', u'以外', u'的', u'蒸籠類', u'餐點']
# u'dtffoodtype',u'列出'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'dtffoodtype',u'吃'
# [u'幫', u'我', u'列出', u'除了', u'有', u'豬肉', u'以外', u'的', u'蒸籠類', u'餐點']
# u'dtffoodtype',u'幫'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'dtffoodtype',u'想'
# [u'幫', u'我', u'列出', u'除了', u'有', u'豬肉', u'以外', u'的', u'蒸籠類', u'餐點']
# u'dtffoodtype',u'有'
# [u'你們', u'的', u'牛肉', u'會不會', u'有', u'含', u'瘦肉精', u'但', u'你們', u'不', u'知道', u'?']
# u'dtffoodsaftyb',u'含'
# [u'是否', u'會', u'含有', u'瘦肉精', u'?']
# u'dtffoodsaftyb',u'含有'
# [u'還是', u'問', u'一下', u'好', u'了', u'，', u'你們', u'的', u'肉類', u'有沒有', u'瘦肉精', u'阿', u'?']
# u'dtffoodsaftyb',u'問'
# [u'最近', u'食安問題', u'很多', u'，', u'你們', u'怎麼', u'證明', u'自家', u'的', u'東西', u'是', u'安全', u'的', u'?']
# u'dtffoodsaftyb',u'是'
# [u'是否', u'會', u'含有', u'瘦肉精', u'?']
# u'dtffoodsaftyb',u'會'
# [u'你們', u'的', u'牛肉', u'會不會', u'有', u'含', u'瘦肉精', u'但', u'你們', u'不', u'知道', u'?']
# u'dtffoodsaftyb',u'有'
# [u'你們', u'的', u'牛肉', u'會不會', u'有', u'含', u'瘦肉精', u'但', u'你們', u'不', u'知道', u'?']
# u'dtffoodsaftyb',u'知道'
# [u'老實', u'說', u'，', u'你們', u'的', u'餐點', u'有沒有', u'瘦肉精', u'?']
# u'dtffoodsaftyb',u'說'
# [u'酸辣湯', u'看起', u'來', u'好', u'豐富', u'，', u'裡面', u'有', u'哪些', u'東西']
# u'dtfsoup',u'來'
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# u'dtfsoup',u'加'
# [u'我', u'想', u'知道', u'酸辣湯', u'裡面', u'有什麼', u'食材']
# u'dtfsoup',u'想'
# [u'你們', u'的', u'酸辣湯', u'放', u'了', u'哪些', u'材料']
# u'dtfsoup',u'放'
# [u'店內', u'的', u'酸辣湯', u'材料', u'有', u'哪些', u'?']
# u'dtfsoup',u'有'
# [u'酸辣湯', u'看起', u'來', u'好', u'豐富', u'，', u'裡面', u'有', u'哪些', u'東西']
# u'dtfsoup',u'看起'
# [u'我', u'想', u'知道', u'酸辣湯', u'裡面', u'有什麼', u'食材']
# u'dtfsoup',u'知道'
# [u'最近', u'食安問題', u'很多', u'，', u'你們', u'怎麼', u'證明', u'自家', u'的', u'東西', u'是', u'安全', u'的', u'?']
# u'dtffoodsaftya',u'是'
# [u'你們', u'的', u'肉類', u'有', u'驗過', u'瘦肉精', u'嗎']
# u'dtffoodsaftya',u'有'
# [u'為什麼', u'信義店', u'只能', u'付現', u'?']
# u'dtfbranch',u'只能'
# [u'除了', u'信義店', u'外', u'，', u'還', u'有', u'其他店', u'不能', u'刷卡', u'嗎', u'?']
# u'dtfbranch',u'有'
# [u'我', u'想', u'吃', u'蒸的', u'東西', u'，', u'但', u'我', u'不能', u'吃', u'豬']
# u'n',u'吃'
# [u'我', u'喜歡', u'你們', u'的', u'茶', u'，', u'可以', u'告訴', u'我', u'是', u'哪種', u'茶', u'嗎', u'?']
# u'n',u'告訴'
# [u'我', u'想', u'知道', u'你們', u'的', u'茶', u'是', u'用', u'甚麼', u'茶葉']
# u'n',u'想'
# [u'你們', u'的', u'茶', u'是', u'什麼', u'茶', u'?']
# u'n',u'是'
# [u'我', u'想', u'知道', u'你們', u'的', u'茶', u'是', u'用', u'甚麼', u'茶葉']
# u'n',u'知道'
# [u'老實', u'說', u'，', u'你們', u'的', u'餐點', u'有沒有', u'瘦肉精', u'?']
# u'n',u'說'
# [u'鼎泰豐', u'所', u'使用', u'的', u'牛肉', u'是', u'哪裡', u'的', u'產地', u'?']
# u'dtfbrand',u'使用'
# [u'鼎泰豐', u'的', u'酸辣湯', u'加', u'了', u'哪些', u'東西']
# u'dtfbrand',u'加'
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# u'dtfbrand',u'屬'
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# u'dtfbrand',u'市售'
# [u'鼎泰豐', u'收', u'信用卡', u'嗎', u'?']
# u'dtfbrand',u'收'
# [u'鼎泰豐', u'賣', u'的', u'是', u'港式點心', u'嗎', u'?']
# u'dtfbrand',u'是'
# [u'鼎泰豐', u'泡菜', u'的', u'味道', u'跟', u'一般', u'不一樣', u'，', u'怎麼', u'會', u'這樣', u'啊', u'?']
# u'dtfbrand',u'會'
# [u'鼎泰豐', u'有', u'素的', u'餐點', u'嗎']
# u'dtfbrand',u'有'
# [u'鼎泰豐', u'賣', u'的', u'是', u'港式點心', u'嗎', u'?']
# u'dtfbrand',u'賣'
# [u'鼎泰豐', u'所', u'使用', u'的', u'牛肉', u'是', u'哪裡', u'的', u'產地', u'?']
# u'dtfingredient',u'使用'
# [u'你們', u'使用', u'的', u'牛肉', u'是', u'美國', u'來', u'的', u'嗎', u'?']
# u'dtfingredient',u'來'
# [u'幫', u'我', u'列出', u'不含', u'豬肉', u'的', u'餐點']
# u'dtfingredient',u'列出'
# [u'我', u'不能', u'吃', u'豬肉']
# u'dtfingredient',u'吃'
# [u'你們', u'的', u'牛肉', u'會不會', u'有', u'含', u'瘦肉精', u'但', u'你們', u'不', u'知道', u'?']
# u'dtfingredient',u'含'
# [u'還是', u'問', u'一下', u'好', u'了', u'，', u'你們', u'的', u'肉類', u'有沒有', u'瘦肉精', u'阿', u'?']
# u'dtfingredient',u'問'
# [u'幫', u'我', u'列出', u'不含', u'豬肉', u'的', u'餐點']
# u'dtfingredient',u'幫'
# [u'我', u'想', u'知道', u'你們', u'用', u'的', u'是', u'哪一國', u'的', u'牛肉']
# u'dtfingredient',u'想'
# [u'鼎泰豐', u'所', u'使用', u'的', u'牛肉', u'是', u'哪裡', u'的', u'產地', u'?']
# u'dtfingredient',u'是'
# [u'有', u'不含', u'豬肉', u'的', u'餐點', u'嗎']
# u'dtfingredient',u'有'
# [u'我', u'想', u'知道', u'你們', u'用', u'的', u'是', u'哪一國', u'的', u'牛肉']
# u'dtfingredient',u'知道'
# [u'你們', u'是', u'進', u'哪裡', u'的', u'牛肉', u'?']
# u'dtfingredient',u'進'
# [u'鼎泰豐', u'賣', u'的', u'是', u'港式點心', u'嗎', u'?']
# u'dtfbranchkindb',u'是'
# [u'你們', u'算', u'港式點心', u'嗎']
# u'dtfbranchkindb',u'算'
# [u'鼎泰豐', u'賣', u'的', u'是', u'港式點心', u'嗎', u'?']
# u'dtfbranchkindb',u'賣'
# [u'店內', u'的', u'消費', u'好像', u'不便宜', u'?']
# u'dtfbranchkinda',u'好像'
# [u'店內', u'服務生', u'的', u'素質', u'都', u'很棒', u'，', u'是否', u'都', u'挑選', u'過', u'?']
# u'dtfbranchkinda',u'挑選'
# [u'店內', u'客人', u'喝', u'的', u'是', u'甚麼', u'茶', u'?']
# u'dtfbranchkinda',u'是'
# [u'國外的分店', u'的', u'餐點', u'和', u'台灣', u'會', u'不一樣', u'嗎', u'?']
# u'dtfbranchkinda',u'會'
# [u'除了', u'信義店', u'外', u'，', u'還', u'有', u'其他店', u'不能', u'刷卡', u'嗎', u'?']
# u'dtfbranchkinda',u'有'
# [u'國外門市', u'賣', u'的', u'東西', u'會', u'比較', u'多樣', u'嗎', u'?']
# u'dtfbranchkinda',u'賣'
# [u'店內', u'客人', u'喝', u'的', u'是', u'甚麼', u'茶', u'?']
# u'dtfbranchkinda',u'喝'
# [u'介紹', u'一下', u'你們', u'的', u'泡菜']
# u'dtfappetizer',u'介紹'
# [u'泡菜', u'是', u'你們', u'自己', u'做', u'的', u'嗎', u'?']
# u'dtfappetizer',u'做'
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# u'dtfappetizer',u'屬'
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# u'dtfappetizer',u'市售'
# [u'鼎泰豐', u'的', u'泡菜', u'和', u'一般', u'市售', u'的', u'泡菜', u'口味', u'不同', u'，', u'請問', u'是', u'屬', u'於', u'何種', u'口味', u'?']
# u'dtfappetizer',u'是'
# [u'鼎泰豐', u'泡菜', u'的', u'味道', u'跟', u'一般', u'不一樣', u'，', u'怎麼', u'會', u'這樣', u'啊', u'?']
# u'dtfappetizer',u'會'
# [u'我', u'想', u'上', u'廁所']
# u'branchinnerinfob',u'想'
# [u'幫', u'我', u'列出', u'素食', u'的', u'餐點']
# u'dtffoodkind',u'列出'
# [u'我', u'吃素', u'，', u'可以', u'吃', u'甚麼', u'?']
# u'dtffoodkind',u'吃'
# [u'幫', u'我', u'列出', u'素食', u'的', u'餐點']
# u'dtffoodkind',u'幫'
# [u'你們', u'的', u'泡菜', u'是', u'台式', u'口味', u'嗎', u'?']
# u'dtffoodkind',u'是'
# [u'有', u'素食', u'的', u'餐點', u'嗎', u'?']
# u'dtffoodkind',u'有'

# %%
# SAVE TO dataframe
NV_NUMPY=np.array(DTF_NV_PAIR)
NV_POS_PAIR = pd.DataFrame(NV_NUMPY)
NV_POS_PAIR.columns = ['NPOS','VTERM']
NV_POS_PAIR.to_pickle('./NV_POS_PAIR')

# %%
#all kind of (A,N) pair

# %%
#==================================================================================================
# 單獨測試 pos pair
#==================================================================================================

# %%
len(set(DTF_N_SET['pos']))

# %%
# Query for specific none on DTF_NV_PAIR
# 取德特定組合內容, 下面的例子是找 dtfsoup 相關所有的 v 的組合
# 也可以翻譯成: 如果出現了 dtfsoup 這個名詞, 整句話可以出現的動詞只能是下面的幾個case
# 當然還要考慮 w2v 的 v, 但不是在這個時候加入
NV_NUMPY=np.array(DTF_NV_PAIR)
idx = np.where(NV_NUMPY[:,0] == u'dtfbranch')
print repr(NV_NUMPY[idx,:]).decode('unicode-escape')
NV_POS_PAIR = pd.DataFrame(NV_NUMPY)
NV_POS_PAIR.columns = ['NPOS','VTERM']

# %%
NN_POS_PAIR
# Out:
#                NPOS   NTERM
# 0           dtfsoup     鼎泰豐
# 1    dtfbranchkindb     鼎泰豐
# 2        ingredient      豬肉
# 3       dtffoodkind      店內
# 4          dtfbrand      泡菜
# 5     dtffoodsaftya     瘦肉精
# 6       dtffoodkind      素的
# 7      dtfappetizer     鼎泰豐
# 8     dtffoodsaftyb      東西
# 9     dtfingredient      宗教
# 10       ingredient      驗過
# 11       ingredient     檢驗過
# 12                n      泡菜
# 13                n      蒸的
# 14   dtfbranchkinda     信義店
# 15       ingredient    產地證明
# 16       ingredient       豬
# 17    dtffoodsaftyb      食材
# 18       ingredient      蒸的
# 19      dtffoodtype      宗教
# 20    dtfingredient       牛
# 21      dtffoodkind     鼎泰豐
# 22      dtffoodtype      因素
# 23        dtfbranch      問題
# 24      dtffoodtype      豬肉
# 25    dtffoodsaftya      東西
# 26      dtffoodkind       媽
# 27    dtffoodsaftyb      肉類
# 28                n      牛肉
# 29    dtffoodsaftya      肉類
# 30   dtfbranchkinda      東西
# 31                n     小籠包
# 32         dtfbrand     檢驗過
# 33         dtfbrand     酸辣湯
# 34         dtfbrand    港式餐廳
# 35    dtfingredient     瘦肉精
# 36   dtfxiaolongbao      面包
# 37       ingredient      證明
# 38       ingredient     瘦肉精
# 39    dtffoodsaftya      食材
# 40                n     信義店
# 41       ingredient    食安問題
# 42         dtfdrink       茶
# 43   dtfbranchkinda     有什麼
# 44                n      吃素
# 45          dtfsoup      材料
# 46   dtfbranchkinda       茶
# 47      dtffoodkind     有什麼
# 48    dtfingredient      東西
# 49         dtfbrand      牛肉
# ..              ...     ...
# 59   dtfbranchkinda    台灣門市
# 60                n       茶
# 61   dtfbranchkinda      材料
# 62        dtfbranch     其他店
# 63          dtfsoup      店內
# 64     dtfappetizer       市
# 65      dtffoodtype      東西
# 66      dtffoodkind      台式
# 67     dtfappetizer      泡菜
# 68                n     瘦肉精
# 69    dtffoodsaftyb      證明
# 70   dtfxiaolongbao     小籠包
# 71    dtffoodsaftyb      牛肉
# 72         dtfbrand    證明文件
# 73   dtfbranchkinda     酸辣湯
# 74                n      東西
# 75         dtfbrand    港式點心
# 76    dtffoodsaftya  檢驗證明文件
# 77      dtffoodtype       豬
# 78    dtfingredient     蒸籠類
# 79          dtfsoup      食材
# 80          dtfsoup      東西
# 81         dtfbrand      素的
# 82         dtfbrand      肉品
# 83         dtfbrand      素食
# 84    dtfingredient     鼎泰豐
# 85       ingredient      食材
# 86       ingredient      店內
# 87       ingredient      素食
# 88    dtfingredient      因素
# 89      dtffoodkind      泡菜
# 90     dtfappetizer      台式
# 91    dtfingredient      豬肉
# 92       ingredient     鼎泰豐
# 93                n     蒸籠類
# 94                n      因素
# 95    dtffoodsaftyb      肉品
# 96       ingredient    小籠湯包
# 97    dtffoodsaftya     鼎泰豐
# 98       ingredient     酸辣湯
# 99         dtfdrink      店內
# 100        dtfbrand      東西
# 101  dtfxiaolongbao     有什麼
# 102    dtfappetizer      韓式
# 103   dtffoodsaftya    檢驗文件
# 104  dtfbranchkinda      素食
# 105         dtfsoup     內容物
# 106   dtfingredient      驗過
# 107               n      豬肉
# 108         dtfsoup     有什麼
#
# [109 rows x 2 columns]

# %%
ALL_VN_PAIR = itertools.product(DTF_V_SET['term'], DTF_N_SET['term'])
list(ALL_VN_PAIR)

# %%
#print repr(DTF_VN_PAIR[10]).decode('unicode-escape')
print 'length DTV_V_SET   = ' + str(len(DTF_V_SET))
print 'length ALL_VN_PAIR = ' + str(len(ALL_VN_PAIR))
print 'length DTF_VN_PAIR = ' + str(len(DTF_VN_PAIR))

# %%
DTF_N_PAIR[0]
if [u'泡菜',u'泡菜'] in DTF_N_PAIR:
    print 'yes'
else:
    print 'no'

# %%
#==================================================================================================
# 以下為測試code
#==================================================================================================

# %%
def check_pos_pair_in_DTFQA(p1,p2):
    ret = 'FALSE'
    for sentence in DTFQA['term']:
        fork_sentence = list(np.array(sentence))
        if p1 in fork_sentence:
            fork_sentence.remove(p1)
        if p2 in fork_sentence_term:
            fork_sentence.remove(p2)  
        if len(sentence) == len(fork_sentence) + 2:
            print repr(sentence).decode('unicode-escape')
            print 'orig_len = ' + str(len(sentence)) + ', after removement =' + str(len(sentence))
            return 'TRUE'
    return ret

# %%
sentence = list(np.array(DTFQA['term'][4]))
#print repr(sentence).decode('unicode-escape')
sentence.append(u'哪時候')
print repr(sentence).decode('unicode-escape')

# %%
p1 = u'哪時候'
p2 = u'人'
if p1 in sentence:
    sentence.remove(p1)
if p2 in sentence:
    sentence.remove(p2)
print repr(sentence).decode('unicode-escape')

# %%
print repr(DTFQA['term'][4]).decode('unicode-escape')

# %%
target_idx = np.where(POS_DETAIL['pos'] == 'n')
POS_DETAIL.iloc[target_idx[0],:]
print len(POS_DETAIL.iloc[target_idx[0],:])

# %%
#np.any([p1*3],DTFTERM0)
print (np.array(DTFTERM4) == p1)

# %%
#print repr(DTFTERM
#print repr(DTFQA['term'][4]).decode('unicode-escape')
DTFTERM0 = DTFQA['term'][0]
DTFTERM4 = DTFQA['term'][4]
print repr(DTFTERM0).decode('unicode-escape')
print repr(DTFTERM4).decode('unicode-escape')

# %%
#print np.array(list(map(lambda v: re.sub(r'dtf','^n$', v) ,POS_DETAIL['pos'])))
#type(POS_DETAIL['pos'])
idx = np.where((POS_DETAIL['pos'] == u'branchinnerinfoa') | (POS_DETAIL['pos'] == 'n'))
POS_DETAIL.iloc[idx[0],:]

# %%
idx = np.array([bool(re.search(u'food', element)) for element in POS_DETAIL['pos']])
print len(POS_DETAIL.iloc[idx,:])
POS_DETAIL.iloc[idx,:]

# %%
pd.set_option("display.max_rows",100)
target_idx = np.where(POS_DETAIL['pos'] == 'n')
POS_DETAIL.iloc[target_idx[0],:]
N_LIST = POS_DETAIL.iloc[target_idx[0],:]
N_LIST

# %%
#all kind of (N,N) pair

pos_list  = []
term_list = []
for idx in range(len(DTFQA['pos'])):
    pos_list  += DTFQA['pos'][idx]
    term_list += DTFQA['term'][idx]

# %%
# 數字有用,文字不行
# create all pair combination in DTFQA.[pos]
# http://stackoverflow.com/questions/1208118/using-numpy-to-build-an-array-of-all-combinations-of-two-arrays
# cartesian
np.array(np.meshgrid([1, 2, 3],[1, 2, 3])).T.reshape(-1,2)
np.array(np.meshgrid([1, 2, 3], [4, 5], [6, 7])).T.reshape(-1,3)

# %%
# cartesian 這個方法不知道怎麼 run
def cartesian2(arrays):
    arrays = [np.asarray(a) for a in arrays]
    shape = (len(x) for x in arrays)

    ix = np.indices(shape, dtype=int)
    ix = ix.reshape(len(arrays), -1).T

    for n, arr in enumerate(arrays):
        ix[:, n] = arrays[n][ix[:, n]]

    return ix

# %%
# cartesian 這個方法數字有用,文字不行
def cartesian_coord(*arrays):
    grid = np.meshgrid(*arrays)        
    coord_list = [entry.ravel() for entry in grid]
    points = np.vstack(coord_list).T
    return points

a = np.array([1,2])
print(cartesian_coord(*2*[a]))

# %%
# cartesian 這個方法文字數字都可以
import itertools
#a_p1 = np.arange(0, 4, 1)
#a_p2 = np.arange(20, 25, 1)
a_p1 = np.array(['a','b'])
a_p2 = np.array(['c','d'])
params = itertools.product(a_p1, a_p2)
for (p1, p2) in params:
    print(p1, p2)

# %%
DTFQA['term']

# %%
params = itertools.product(DTF_N_SET['term'], DTF_N_SET['term'])
for (p1, p2) in params:
    print repr(p1).decode('unicode-escape') + ',' + repr(p2).decode('unicode-escape')

# %%
aList = [123, 'xyz', 'zara', 'abc', 'xyz'];

aList.remove('xyz');
print "List : ", aList
aList.remove('abc');
print "List : ", aList

# %%
for idx in range(len(DTFQA)):
    sentence_term = DTFQA['term'][idx]
    print sentence_term                 
                  
    #print sentence_pos

# %%
DTFQA['term'][0]
